# %%
import os 
from pathlib import Path
import sys
import subprocess
import time

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

def split_into_graphs_help(lines: list[str], graphs: list[list[str]]):
    for line in lines:
        if "detected" in line or "execution explored" in line or "wall-clock time" in line:
            return graphs
        elif line == "\n" or line == "":
            continue
        elif "Execution Graph" in line:
            graphs.append([])
        else:
            graphs[-1].append(line)
    return graphs

def merge_strs(xss: list[list[str]]) -> list[object]:
    res = []
    for xs in xss:
        res.append("\n".join(xs))
    return res
        
def split_into_graphs(lines: list[str]):
    return merge_strs(split_into_graphs_help(lines, []))

def get_genmc_path() -> Path:
    return Path('/root') / 'genmc-xmm' / 'genmc'

def list_test_paths() -> [Path]:
    tests_path = Path('/root') / 'xmm-benchmarks' / 'tests'
    assert os.path.isdir(tests_path)
    tests = os.listdir(tests_path)
    tests.sort()
    xs = [tests_path / test for test in tests]
    return [x for x in xs if os.path.isdir(x)]

def print_result(path, testname, execs, dups, expected, dirname):
    if execs == expected:
        print(bcolors.OKGREEN, f"PASSED ({execs} executions, {dups} duplicates)", path / testname, bcolors.ENDC)
    elif dirname in expected_fails:
        print(bcolors.OKBLUE, "EXPECTED FAILED", path / testname, "expected", expected, "got (", execs, "executions, ", dups, " duplicates)", bcolors.ENDC)
    else:
        print(bcolors.FAIL, "FAILED", path / testname, "expected", expected, "got (", execs, "executions, ", dups, " duplicates)", bcolors.ENDC)

def get_digits_after(pattern: str, string: str):
    index = string.index(pattern) 
    assert(index >= 0)
    index += len(pattern)

    num_part_len = 0
    for c in string[index:]:
        if c.isdigit():
            num_part_len += 1
        else:
            break
    
    assert(num_part_len > 0)
    num_str = string[index:index+num_part_len]
    return int(num_str)


def test_xmm(test_path: Path):
    xmm_expected_file = test_path / "expected.xmm.in"
    if not os.path.isfile(xmm_expected_file):
        print("expected.xmm.in not found for ", test_path)
        return

    print("")
    dirname = test_path.name
    print(dirname)
    
    xmm_expected = None
    with open(xmm_expected_file) as f:
        xmm_expected_str = f.read()
        try:
            xmm_expected = int(xmm_expected_str)
        except ValueError:
            print(f"could not convert contents of {xmm_expected_file}: {xmm_expected_str} to int value")
            exit(1)
    
    variants_path = test_path / "variants"
    for variant in os.listdir(variants_path):
        genmc_result = subprocess.run([genmc_path, "--print-exec-graphs", "--XMM", variants_path / variant], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        genmc_output = genmc_result.stdout.decode()
        genmc_output_stderr = genmc_result.stderr.decode()

        if genmc_result.returncode != 0:
            print("genmc exited with exit code ", genmc_result.returncode)
            print(variants_path / variant)
            print(genmc_output)
            print(genmc_output_stderr)
            exit(1)
        
        execs = get_digits_after("Number of complete executions explored: ", genmc_output)
        dups = get_digits_after("Number of duplicate executions explored: ", genmc_output)
        print_result(variants_path, variant, execs, dups, xmm_expected, dirname)
        if dirname in expected_fails:
            continue

        combined_output = genmc_output_stderr + genmc_output
        variantname = variant.split('.')[0]
        with open(test_path / f"expected.xmm.output.{variantname}", "r") as f:
            contents = f.read()
            actual = set(split_into_graphs(combined_output.split("\n")))
            expected = set(split_into_graphs(contents.split("\n")))
            for e in expected:
                if e not in actual:
                    print(bcolors.FAIL, "FAILED", variants_path / variant, "missing graph\n", e, bcolors.ENDC)
            for a in actual:
                if a not in expected:
                    print(bcolors.FAIL, "FAILED", variants_path / variant, "unexpected graph\n", a, bcolors.ENDC)

genmc_path = get_genmc_path()
test_paths = list_test_paths()
for path in test_paths:
    assert os.path.isdir(path)

expected_fails = set(["LB+coh-cyc", "LB+coh-cyc+Wd", "LB+porf-suffix"])

argv = sys.argv
start_time = time.time()
for path in test_paths:
    test_xmm(path)
delta_t = time.time() - start_time
print(f"Total execution time: {delta_t:.3f}s")
# Out:
# LB
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB/variants/lb0.c
#
# LB+CoRR
#  PASSED (14 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+CoRR/variants/lb+corr0.c
#
# LB+CoRRx
#  PASSED (22 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+CoRRx/variants/lb+corrx0.c
#
# LB+LB
#  PASSED (9 executions, 10 duplicates) /root/xmm-benchmarks/tests/LB+LB/variants/lb+lb0.c
#
# LB+LB+if
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+LB+if/variants/lb+lb+if0.c
#
# LB+LB+if-reversed
#  PASSED (5 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB+LB+if-reversed/variants/lb+lb+if0.c
#
# LB+RR-same-loc
#  PASSED (6 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+RR-same-loc/variants/main0.c
#
# LB+SB
#  PASSED (16 executions, 23 duplicates) /root/xmm-benchmarks/tests/LB+SB/variants/lb+sb0.c
#
# LB+W
#  PASSED (12 executions, 4 duplicates) /root/xmm-benchmarks/tests/LB+W/variants/lb+w0.c
#  PASSED (12 executions, 4 duplicates) /root/xmm-benchmarks/tests/LB+W/variants/lb+w1.c
#
# LB+W+data
#  PASSED (12 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+W+data/variants/lb+w+data1.c
#  PASSED (12 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+W+data/variants/lb+w+data0.c
#
# LB+Wd
#  PASSED (6 executions, 4 duplicates) /root/xmm-benchmarks/tests/LB+Wd/variants/lb+wd0.c
#
# LB+Wd+deps
#  PASSED (7 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+Wd+deps/variants/lb+wd+deps0.c
#
# LB+acq
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+acq/variants/lb+acq0.c
#
# LB+acq+rel
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+acq+rel/variants/lb+acq+rel1.c
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+acq+rel/variants/lb+acq+rel0.c
#
# LB+cert-rev
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+cert-rev/variants/lb+cert-rev0.c
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+cert-rev/variants/lb+cert-rev1.c
#
# LB+coh
#  PASSED (4 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+coh/variants/lb+coh0.c
#
# LB+coh+RR
#  PASSED (21 executions, 11 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR/variants/lb+coh+rr0.c
#  PASSED (21 executions, 15 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR/variants/lb+coh+rr2.c
#  PASSED (21 executions, 15 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR/variants/lb+coh+rr1.c
#
# LB+coh+RR+cf
#  PASSED (36 executions, 15 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR+cf/variants/lb+coh+rr+cf1.c
#  PASSED (36 executions, 15 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR+cf/variants/lb+coh+rr+cf0.c
#  PASSED (36 executions, 22 duplicates) /root/xmm-benchmarks/tests/LB+coh+RR+cf/variants/lb+coh+rr+cf2.c
#
# LB+coh+cas
#  PASSED (2 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+coh+cas/variants/lb+coh+cas0.c
#
# LB+coh+fadd
#  PASSED (2 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+coh+fadd/variants/lb+coh+fadd0.c
#
# LB+coh+fadd+fadd
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+coh+fadd+fadd/variants/lb+coh+fadd+fadd0.c
#
# LB+coh+fadd+fsub
#  PASSED (2 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+coh+fadd+fsub/variants/lb+coh+fadd+fsub0.c
#
# LB+coh-cyc
#  EXPECTED FAILED /root/xmm-benchmarks/tests/LB+coh-cyc/variants/lb+coh-cyc0.c expected 8 got ( 6 executions,  1  duplicates)
#
# LB+coh-cyc+Wd
#  EXPECTED FAILED /root/xmm-benchmarks/tests/LB+coh-cyc+Wd/variants/lb+coh-cyc+wd0.c expected 16 got ( 12 executions,  2  duplicates)
#
# LB+ctrl
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+ctrl/variants/lb+ctrl0.c
#
# LB+data
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+data/variants/lb+data0.c
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB+data/variants/lb+data1.c
#
# LB+equals
#  PASSED (10 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB+equals/variants/main0.c
#
# LB+fake-ctrl
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+fake-ctrl/variants/lb+fake-ctrl0.c
#
# LB+fake-data
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+fake-data/variants/lb+fake-data0.c
#
# LB+porf-suffix
#  EXPECTED FAILED /root/xmm-benchmarks/tests/LB+porf-suffix/variants/main0.c expected 12 got ( 11 executions,  5  duplicates)
#
# LB+porf-views-1
#  PASSED (11 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB+porf-views-1/variants/lb+porf-views-10.c
#  PASSED (11 executions, 4 duplicates) /root/xmm-benchmarks/tests/LB+porf-views-1/variants/lb+porf-views-11.c
#
# LB+porf-views-2
#  PASSED (4 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB+porf-views-2/variants/lb+porf-views-20.c
#  PASSED (4 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB+porf-views-2/variants/lb+porf-views-21.c
#
# LB+rel
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/LB+rel/variants/lb+rel0.c
#
# LB+seq-src
#  PASSED (20 executions, 11 duplicates) /root/xmm-benchmarks/tests/LB+seq-src/variants/main0.c
#
# LB+seq-tgt
#  PASSED (9 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB+seq-tgt/variants/main0.c
#
# LB-DRF
#  PASSED (3 executions, 0 duplicates) /root/xmm-benchmarks/tests/LB-DRF/variants/lb-drf0.c
#
# LB-DRF-LL
#  PASSED (5 executions, 4 duplicates) /root/xmm-benchmarks/tests/LB-DRF-LL/variants/lb-drf-ll0.c
#
# LB-DRF-SLI
#  PASSED (5 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB-DRF-SLI/variants/lb-drf-sli0.c
#
# LB-DRF-SLI-Simpl
#  PASSED (7 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB-DRF-SLI-Simpl/variants/main0.c
#
# LB-invis-write+dep
#  PASSED (3 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB-invis-write+dep/variants/lb-invis-write+dep0.c
#
# LB3
#  PASSED (8 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB3/variants/lb30.c
#
# LB3+porf-views-1
#  PASSED (21 executions, 3 duplicates) /root/xmm-benchmarks/tests/LB3+porf-views-1/variants/lb3+porf-views-10.c
#
# LB3+porf-views-2
#  PASSED (8 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB3+porf-views-2/variants/lb3+porf-views-20.c
#  PASSED (8 executions, 1 duplicates) /root/xmm-benchmarks/tests/LB3+porf-views-2/variants/lb3+porf-views-21.c
#
# LBn
#  PASSED (1024 executions, 10 duplicates) /root/xmm-benchmarks/tests/LBn/variants/lbn0.c
#
# LBn+ctrl
#  PASSED (11 executions, 1 duplicates) /root/xmm-benchmarks/tests/LBn+ctrl/variants/lbn+ctrl0.c
#
# LBn+data
#  PASSED (1024 executions, 1 duplicates) /root/xmm-benchmarks/tests/LBn+data/variants/lbn+data0.c
#
# LBn-pairs
#  PASSED (1024 executions, 2184 duplicates) /root/xmm-benchmarks/tests/LBn-pairs/variants/lbn-pairs0.c
#
# R-bot-multi-matching
#  PASSED (21 executions, 9 duplicates) /root/xmm-benchmarks/tests/R-bot-multi-matching/variants/main0.c
#
# WMC-test1
#  PASSED (7 executions, 3 duplicates) /root/xmm-benchmarks/tests/WMC-test1/variants/main.c
#
# WMC-test2
#  PASSED (12 executions, 6 duplicates) /root/xmm-benchmarks/tests/WMC-test2/variants/main.c
#
# porf-prefix
#  PASSED (7 executions, 3 duplicates) /root/xmm-benchmarks/tests/porf-prefix/variants/main.c
#
# riwi
#  PASSED (4 executions, 1 duplicates) /root/xmm-benchmarks/tests/riwi/variants/riwi0.c
#
# test1
#  PASSED (4 executions, 1 duplicates) /root/xmm-benchmarks/tests/test1/variants/test0.c
#
# test10
#  PASSED (8 executions, 2 duplicates) /root/xmm-benchmarks/tests/test10/variants/test0.c
#
# test11
#  PASSED (16 executions, 18 duplicates) /root/xmm-benchmarks/tests/test11/variants/test0.c
#
# test12
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/test12/variants/test0.c
#
# test13
#  PASSED (1 executions, 0 duplicates) /root/xmm-benchmarks/tests/test13/variants/test0.c
#
# test14
#  PASSED (1 executions, 0 duplicates) /root/xmm-benchmarks/tests/test14/variants/test0.c
#
# test15
#  PASSED (2 executions, 0 duplicates) /root/xmm-benchmarks/tests/test15/variants/test0.c
#
# test16
#  PASSED (4 executions, 0 duplicates) /root/xmm-benchmarks/tests/test16/variants/test0.c
#
# test17
#  PASSED (9 executions, 3 duplicates) /root/xmm-benchmarks/tests/test17/variants/test0.c
#
# test18
#  PASSED (9 executions, 3 duplicates) /root/xmm-benchmarks/tests/test18/variants/test0.c
#
# test19
#  PASSED (20 executions, 11 duplicates) /root/xmm-benchmarks/tests/test19/variants/test0.c
#
# test2
#  PASSED (5 executions, 1 duplicates) /root/xmm-benchmarks/tests/test2/variants/test0.c
#
# test20
#  PASSED (20 executions, 11 duplicates) /root/xmm-benchmarks/tests/test20/variants/test0.c
#
# test3
#  PASSED (18 executions, 2 duplicates) /root/xmm-benchmarks/tests/test3/variants/test0.c
#
# test4
#  PASSED (4 executions, 2 duplicates) /root/xmm-benchmarks/tests/test4/variants/test0.c
#
# test5
#  PASSED (28 executions, 10 duplicates) /root/xmm-benchmarks/tests/test5/variants/test0.c
#
# test6
#  PASSED (3 executions, 1 duplicates) /root/xmm-benchmarks/tests/test6/variants/test0.c
#
# test7
#  PASSED (8 executions, 4 duplicates) /root/xmm-benchmarks/tests/test7/variants/test0.c
#
# test8
#  PASSED (4 executions, 1 duplicates) /root/xmm-benchmarks/tests/test8/variants/test0.c
#
# test9
#  PASSED (12 executions, 2 duplicates) /root/xmm-benchmarks/tests/test9/variants/test0.c
#
# test9a
#  PASSED (12 executions, 2 duplicates) /root/xmm-benchmarks/tests/test9a/variants/test0.c
# Total execution time: 7.301s
